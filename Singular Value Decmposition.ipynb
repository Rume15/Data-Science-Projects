# %% [markdown]
# Recap for today
#
# 1. Matrix computation using python
# 2. Statistics and Linear ALgebra
# 3. Applications - User Recommendation systems
#                 - Google page Algorithm
#                 -Fraud in Bank Transactions using matrix algebra
#                 -Machine Learning ...
#                 etc
#                 CAT -50% and Exam -50%
#                 CAT Project: -concept papers - 10%
#                 Project Assesment
#                 Concept paper             5% - Frst week of January
#                 Oral Examination Seminar 15% - Before Exams
#                 Final Project Report     30%-Before Exams

# %% [markdown]
# We can use Singular Value Decomposition (SVD) to recommend other movies based on user rating

# %%
from numpy import array
# define a matrix 
v=array([1,2,3,4,5])
print(v.T)
A=array([[1,2],
        [2,4],
        [3,5],
        [4,6]])
print(A)
# Out:
# [1 2 3 4 5]
# [[1 2]
#  [2 4]
#  [3 5]
#  [4 6]]

# %%
from IPython.display import Image
url='https://www.uonbi.ac.ke/sites/default/files/old%20pic%20uon%20great%20court.jpg'
Image(url,width=900)

# %%
import IPython
url='https://www.uonbi.ac.ke/sites/default/files/old%20pic%20uon%20great%20court.jpg'
IPython.display.Image(url,width=900)
import numpy as np
import matplotlib.pyplot as plt
import time
from PIL import Image
img = Image.open('UON.jpg')
plt.figure(figsize=(10,8))
plt.imshow(img)

# %%
imggrey=img.convert('LA')
plt.figure(figsize=(6,9))
plt.imshow(img);
plt.imshow(imggrey);
im

# %%
imgmat=np.array(list(imggrey).getdata(band=0),float)
imgmat.shape=(imggrey.size[1],imggrey.size[0])
imgmat=np.matrix(imgmat)
plt.figure(figsize=(6,9))
plt.imshow(imgmat, cmap='gray');
print(imgmat)

imgmat.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 imgmat=np.array(list(imggrey).getdata(band=0),float)
#       2 imgmat.shape=(imggrey.size[1],imggrey.size[0])
#       3 imgmat=np.matrix(imgmat)
#
# TypeError: 'Image' object is not iterable

# %% [markdown]
# U, sigma, V=np.linalg.svd(imgmat)

# %%
reconimg=np.matrix(U:, :1)*np.diag(sigma[:1])*np.matrix(V[:1,:1])
plt.imshow(reconimg, cmap='gray');
# Out:
#   Cell In[40], line 1
#     reconimg=np.matrix(U:, :1)*np.diag(sigma[:1])*np.matrix(V[:1,:1])
#                         ^
# SyntaxError: invalid syntax

# %%
for i in range (1,5):
    reconimg=np.matrix(U[:, :1])*np.diag(sigma[:i])*np.matrix(V[:i,:])
plt.imshow(reconimg, cmap='gray');
title="n=%S"% i  
plt.title(title)
plt.imshow()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 for i in range (1,5):
# ----> 2     reconimg=np.matrix(U[:, :1])*np.diag(sigma[:i])*np.matrix(V[:i,:])
#       3 plt.imshow(reconimg, cmap='gray');
#       4 title="n=%S"% i
#
# NameError: name 'U' is not defined
